# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,f1_score,precision_score,confusion_matrix,recall_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier

# %%
df=pd.read_csv("C:\\Users\\Basant\\Desktop\\New folder 101\\github\\data\\creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.drop(['Time'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15  9.604066e-16
# std    1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00  1.380247e+00
# min   -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00 -1.137433e+02
# 25%   -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01 -6.915971e-01
# 50%    1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02 -5.433583e-02
# 75%    1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01  6.119264e-01
# max    2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01  3.480167e+01
#
#                  V6            V7            V8            V9           V10  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15  2.239053e-15
# ...

# %%
df.duplicated().sum()
# Out:
# 9144

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (275663, 30)

# %%
sns.countplot(x='Class',data=df)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
fraud=df[df['Class']==1]
loyal=df[df['Class']==0]
print('Fraud: ',len(fraud))
print('loyal: ',len(loyal))
# Out:
# Fraud:  473
# loyal:  275190

# %%
X=df.drop(['Class'],axis=1)
y=df['Class']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.3,random_state=42)
print(X_train.shape,X_test.shape)
# Out:
# (192964, 29) (82699, 29)

# %%
scaler = StandardScaler()
X_train['Amount'] = scaler.fit_transform(X_train['Amount'].values.reshape(-1, 1))
X_test['Amount'] = scaler.transform(X_test['Amount'].values.reshape(-1, 1))

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
X_train_os,y_train_os=sm.fit_resample(X_train,y_train)

# %%
print(X_train_os.shape,X_test.shape)
# Out:
# (385254, 29) (82699, 29)

# %%
lor=LogisticRegression()
lor.fit(X_train_os,y_train_os)
pred5=lor.predict(X_test)
# Out:
# C:\Users\Basant\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy_score(y_test,pred5)
# Out:
# 0.9751629403015756

# %%
recall_score(y_test,pred5)
# Out:
# 0.8970588235294118

# %%
precision_score(y_test,pred5)
# Out:
# 0.056429232192414434

# %%
f1_score(y_test,pred5)
# Out:
# 0.1061792863359443

# %%
confusion_matrix(y_test,pred5)
# Out:
# array([[80523,  2040],
#        [   14,   122]], dtype=int64)

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train_os,y_train_os)
pred6=dt.predict(X_test)

# %%
accuracy_score(y_test,pred6)
# Out:
# 0.9976299592498096

# %%
recall_score(y_test,pred6)
# Out:
# 0.7720588235294118

# %%
precision_score(y_test,pred6)
# Out:
# 0.3888888888888889

# %%
f1_score(y_test,pred6)
# Out:
# 0.5172413793103449

# %%
confusion_matrix(y_test,pred6)
# Out:
# array([[82398,   165],
#        [   31,   105]], dtype=int64)

# %%
rf=RandomForestClassifier()
rf.fit(X_train_os,y_train_os)
pred7=rf.predict(X_test)

# %%
accuracy_score(y_test,pred7)
# Out:
# 0.9994558579910277

# %%
recall_score(y_test,pred7)
# Out:
# 0.8235294117647058

# %%
precision_score(y_test,pred7)
# Out:
# 0.8421052631578947

# %%
f1_score(y_test,pred7)
# Out:
# 0.83271375464684

# %%
confusion_matrix(y_test,pred7)
# Out:
# array([[82542,    21],
#        [   24,   112]], dtype=int64)

# %%
value=np.array([[accuracy_score(y_test,pred5),recall_score(y_test,pred5),precision_score(y_test,pred5),f1_score(y_test,pred5)],
                [accuracy_score(y_test,pred6),recall_score(y_test,pred6),precision_score(y_test,pred6),f1_score(y_test,pred6)],
                [accuracy_score(y_test,pred7),recall_score(y_test,pred7),precision_score(y_test,pred7),f1_score(y_test,pred7)]])

final=pd.DataFrame(value,index=['LOR','DT','RF'],columns=['accuracy score','recall_score','precision_score','f1_score'])
final
# Out:
#      accuracy score  recall_score  precision_score  f1_score
# LOR        0.975163      0.897059         0.056429  0.106179
# DT         0.997630      0.772059         0.388889  0.517241
# RF         0.999456      0.823529         0.842105  0.832714

# %%
sns.barplot(x=final.index,y=final['accuracy score'])
# Out:
# <Axes: ylabel='accuracy score'>

# %%
sns.heatmap(final,annot=True)
# Out:
# <Axes: >

# %%
final.columns
# Out:
# Index(['accuracy score', 'recall_score', 'precision_score', 'f1_score'], dtype='object')

# %%
fig, ax = plt.subplots()
im = ax.imshow(final)
# Show all ticks and label them with the respective list entries
ax.set_yticks(np.arange(len(final.index)), labels=final.index)
ax.set_xticks(np.arange(len(final.columns)), labels=final.columns)


# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(final.shape[0]):
    for j in range(final.shape[1]):
        text = ax.text(j, i, round(final.iloc[i, j],3),
                       ha="center", va="center", color="w")

ax.set_title("matrices")
fig.tight_layout()
plt.show()

# %%
X_test
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 275693 -0.190398  0.698232  1.396916  1.243184  0.063649 -0.053054  0.586590
# 94607  -2.899712  1.147393 -0.379727 -2.019742 -0.850174 -0.542774 -0.282444
# 283229 -5.900967  5.307300 -5.032880 -0.777607 -2.932475 -1.526561 -2.838857
# 56997  -1.079251  0.175778  1.951516 -1.261280  0.354781 -0.661683  0.373771
# 33012   1.211723 -1.048916  0.811722 -0.615885 -1.230005  0.314754 -1.137566
# ...          ...       ...       ...       ...       ...       ...       ...
# 81133   1.147613 -0.046920  0.721177  0.990294 -0.794443 -0.775272 -0.059036
# 64955  -2.160532 -0.027583  1.018225 -0.369923  1.404875 -0.848959  0.138431
# 185354 -0.774602 -0.988419 -0.664368  1.001981 -0.601821 -0.117035  2.450352
# 91031  -1.689512  1.228802  0.804222 -0.324419  0.177404 -0.143295  0.705853
# 15058  -1.207592  1.807145  0.118035 -0.106946 -0.170029 -0.614952  0.018613
#
# ...

# %%
# Initialize the XGBoost classifier
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# Train the model
xgb.fit(X_train_os, y_train_os)

# Make predictions
pred8 = xgb.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# C:\Users\Basant\anaconda3\Lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# Accuracy: 0.98

# %%
accuracy_score(y_test,pred8)
# Out:
# 0.9992502932320826

# %%
recall_score(y_test,pred8)
# Out:
# 0.8455882352941176

# %%
precision_score(y_test,pred8)
# Out:
# 0.7371794871794872

# %%
f1_score(y_test,pred8)
# Out:
# 0.7876712328767123

# %%
confusion_matrix(y_test,pred8)
# Out:
# array([[82522,    41],
#        [   21,   115]], dtype=int64)

# %%
value=np.array([[accuracy_score(y_test,pred5),recall_score(y_test,pred5),precision_score(y_test,pred5),f1_score(y_test,pred5)],
                [accuracy_score(y_test,pred6),recall_score(y_test,pred6),precision_score(y_test,pred6),f1_score(y_test,pred6)],
                [accuracy_score(y_test,pred7),recall_score(y_test,pred7),precision_score(y_test,pred7),f1_score(y_test,pred7)],
               [accuracy_score(y_test,pred8),recall_score(y_test,pred8),precision_score(y_test,pred8),f1_score(y_test,pred8)]])

final=pd.DataFrame(value,index=['LOR','DT','RF','XGB'],columns=['accuracy score','recall_score','precision_score','f1_score'])
final
# Out:
#      accuracy score  recall_score  precision_score  f1_score
# LOR        0.975163      0.897059         0.056429  0.106179
# DT         0.997630      0.772059         0.388889  0.517241
# RF         0.999456      0.823529         0.842105  0.832714
# XGB        0.999250      0.845588         0.737179  0.787671

# %%
fig, ax = plt.subplots()
im = ax.imshow(final)
# Show all ticks and label them with the respective list entries
ax.set_yticks(np.arange(len(final.index)), labels=final.index)
ax.set_xticks(np.arange(len(final.columns)), labels=final.columns)


# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(final.shape[0]):
    for j in range(final.shape[1]):
        text = ax.text(j, i, round(final.iloc[i, j],3),
                       ha="center", va="center", color="w")

ax.set_title("matrices")
fig.tight_layout()
plt.show()
